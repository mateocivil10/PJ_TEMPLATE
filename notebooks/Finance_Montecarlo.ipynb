# %%
import yfinance as yf
import pandas as pd

# %%
# 1. Especificar el ticker de la acción
ticker = 'AAPL'  # Aquí puedes poner el ticker que desees, por ejemplo, AAPL para Apple

# 2. Descargar los precios históricos usando yfinance
data = yf.download(ticker, start="2014-01-01", end="2024-01-01")  # Especificamos el rango de fechas

# 3. Visualizar los primeros registros
print(data.head())

# 4. Opcional: Graficar los precios de cierre
import matplotlib.pyplot as plt

data['Close'].plot(title=f"Precio de Cierre de {ticker}")
plt.show()
# Out:
# Failed to get ticker 'AAPL' reason: HTTPSConnectionPool(host='fc.yahoo.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Unable to connect to proxy', OSError('Tunnel connection failed: 407 Proxy Authentication Required')))
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
# Matplotlib is building the font cache; this may take a moment.
